# %% [markdown]
# This is the beginning.

# %%
import pandas as pd
import data_config_own as cfg_own

df_raw = pd.read_csv('./data/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv')
#print(df_raw.dtypes.values);
cfg_own.save_info(df_raw, fname='dataset_info.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 6
#       4 df_raw = pd.read_csv('./data/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv')
#       5 #print(df_raw.dtypes.values);
# ----> 6 cfg_own.save_info(df_raw, fname='dataset_info.csv')
#
# AttributeError: module 'data_config_own' has no attribute 'save_info'

# %% [markdown]
# we create info file above.

# %%
df = cfg.adjust_resale_price(df_raw, cut_off_date='2024-04-01')
cfg.visualize_adjusted_price(df[['month', 'resale_price', 'adjusted_price']].copy(), fname='adjusted_price.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 df = cfg.adjust_resale_price(df_raw, cut_off_date='2024-04-01')
# ----> 2 cfg.visualize_adjusted_price(df[['month', 'resale_price', 'adjusted_price']].copy(), fname='adjusted_price.png')
#
# File ~\Projects\RegressionProject\data_config.py:110, in visualize_adjusted_price(df, fname)
#     108 plt.xticks(rotation=45)
#     109 plt.tight_layout()
# --> 110 plt.savefig('./imgs/' + fname, dpi=700)
#
# File ~\anaconda3\envs\myenv\Lib\site-packages\matplotlib\pyplot.py:1223, in savefig(*args, **kwargs)
#    1220 fig = gcf()
#    1221 # savefig default implementation has no return, so mypy is unhappy
#    1222 # presumably this is here because subclasses can return?
# -> 1223 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
# ...

# %%
df_clean = cfg.preprocess_data(df)
print(df_raw.shape, df.shape, df_clean.shape)
df_clean.to_csv('./data/SGHDB2017-2024_clean.csv', index=False)
# Out:
# (202492, 11) (175657, 15) (175657, 52)

# %% [markdown]
# Here we begin building our model.
